# %% [markdown]
# ## More sophisticated regression models

# %%
cd I:/wpwp/Scraping
# Out:
# I:\wpwp\Scraping

# %%
cd D:/mfruman/Documents/wpwp/Python
# Out:
# D:\mfruman\Documents\wpwp\Python

# %%
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
import wURegression as Reg
reload(Reg)
# Out:
# <module 'wURegression' from 'wURegression.pyc'>

# %% [markdown]
# ### One-city, single-day model

# %%
# regression model using data from one city on a single day
# to predict maximum temperature the next day
featureData, target, model_params = Reg.oneCityModel('CYYZ','2005-01-01','2010-12-31',\
                                                     ['TempMax','dailyTempRange',\
                                                     'PressMax','dailyPressRange',\
                                                     'HumidityMean',\
                                                     'isWesterly','isSoutherly',\
                                                     'isFoggy',\
                                                     'isMorningMinTemp', 'isMorningMaxTemp', \
                                                     'isDaytimeMinPress', 'isDaytimeMaxPress', \
                                                     'isMorningMaxWind'], \
                                                     targetVar='TempMax',lag=1,scale=True)
# Out:
# R^2: 0.900706679029
# Regression coefficients (scaled, sorted):
#   intercept:	13.198630137
#   TempMax:	10.4304663521
#   isWesterly:	-0.70218527205
#   dailyTempRange:	0.570219939925
#   isMorningMinTemp:	0.524713736424
#   isDaytimeMinPress:	-0.475707214073
#   isMorningMaxWind:	0.363261144687
#   isDaytimeMaxPress:	0.347783256711
#   PressMax:	0.347778747571
#   isMorningMaxTemp:	-0.28161540323
#   HumidityMean:	0.226287705325
#   isFoggy:	0.0886469482693
#   dailyPressRange:	-0.0160820841416
#   isSoutherly:	0.013542292786

# %%
# out-of-sample prediction
date_list, pred, target, model_perf = Reg.oneCityPredict(model_params, \
                                                         '2011-01-01', '2012-12-31', \
                                                         actual=True)
# Out:
# R^2_mean:	0.881878883471
# R^2_base:	0.25142776461
# RMSE:		3.76056679243
# RMSE_base:	4.34646762578

# %%
# plot comparison
ax = Reg.plotModelPred(date_list, pred, target, showIt=False)
ax.set_title('One-city, single-day model prediction for CYYZ')
ax.set_ylabel('Temperature (C)')
plt.show()

ax = Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300, showIt=False)
ax.set_title('One-city, single-day model prediction for CYYZ')
ax.set_ylabel('Temperature (C)')
plt.show()

# %% [markdown]
# ### One-city, multi-day model

# %%
# using data from one city on multiple days ("Taylor model")
pred0 = pred[2:]  # save simple model prediction (for comparison plot)
featureData, target, model_params = Reg.oneCityTaylorModel('CYYZ','2005-01-01','2010-12-31',\
                                                           ['TempMax','dailyTempRange',\
                                                            'PressMax','dailyPressRange',\
                                                            'HumidityMean',\
                                                            'isWesterly','isSoutherly',\
                                                            'isFoggy',\
                                                            'isMorningMinTemp', 'isMorningMaxTemp', \
                                                            'isDaytimeMinPress', 'isDaytimeMaxPress', \
                                                            'isMorningMaxWind'], \
                                                            targetVar='TempMax',lag=1,order=2,scale=True)
# Out:
# R^2: 0.911483764053
# Regression coefficients (scaled, sorted):
#   intercept:	13.2061243144
#   0th deriv of TempMax:	10.6137295049
#   1th deriv of TempMax:	-1.46744420454
#   1th deriv of dailyTempRange:	1.11832090512
#   1th deriv of isMorningMinTemp:	-1.11635584991
#   2th deriv of dailyTempRange:	-0.88652274137
#   1th deriv of isSoutherly:	0.875601773693
#   0th deriv of isMorningMinTemp:	0.734627671225
#   2th deriv of isMorningMinTemp:	0.732426488047
#   0th deriv of isWesterly:	-0.723396930792
#   2th deriv of TempMax:	0.691497612978
#   1th deriv of PressMax:	0.634973291318
#   0th deriv of dailyTempRange:	0.515665680505
#   1th deriv of isWesterly:	0.497856015798
#   1th deriv of HumidityMean:	0.489556357309
#   1th deriv of isDaytimeMaxPress:	0.424528516311
#   2th deriv of PressMax:	-0.370511278926
#   2th deriv of isSoutherly:	-0.368643072278
#   1th deriv of isMorningMaxWind:	0.322344954735
#   1th deriv of isMorningMaxTemp:	-0.267954663849
#   0th deriv of dailyPressRange:	-0.265754877267
#   0th deriv of isDaytimeMinPress:	-0.240210046694
#   2th deriv of isDaytimeMaxPress:	-0.236896176122
#   0th deriv of isSoutherly:	-0.2157807569
#   1th deriv of dailyPressRange:	0.205128192403
#   2th deriv of isWesterly:	-0.198455591175
#   2th deriv of isFoggy:	-0.193536631034
#   0th deriv of PressMax:	0.178687051535
#   2th deriv of dailyPressRange:	-0.174097896932
#   2th deriv of HumidityMean:	-0.151669301703
#   0th deriv of HumidityMean:	0.126788210401
#   2th deriv of isMorningMaxWind:	-0.122532758984
#   0th deriv of isFoggy:	0.1186539762
#   0th deriv of isMorningMaxTemp:	-0.117250457941
#   1th deriv of isDaytimeMinPress:	-0.116996811622
#   1th deriv of isFoggy:	0.111211531936
#   0th deriv of isMorningMaxWind:	0.108423318387
#   0th deriv of isDaytimeMaxPress:	0.0886056936987
#   2th deriv of isDaytimeMinPress:	-0.0743973010931
#   2th deriv of isMorningMaxTemp:	0.0650813936751

# %%
# out-of-sample prediction
date_list, pred, target, model_perf = Reg.oneCityTaylorPredict(model_params, \
                                                               '2011-01-01', '2012-12-31', \
                                                               actual=True)
pred1 = pred
# Out:
# R^2_mean:	0.897968201664
# R^2_base:	0.350394112977
# RMSE:		3.49242958146
# RMSE_base:	4.33313961246

# %%
# plot comparison
ax = Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300, showIt=False)
plt.plot(date_list[200:300],pred0[200:300],color='green')
plt.scatter(date_list[200:300],pred0[200:300],color='green')
plt.legend(['Truth','Multi-dat','Single-day'])
ax.set_title('One-city, multi-day model prediction for CYYZ')
ax.set_ylabel('Temperature (C)')
plt.show()

# %%
# compare errors from simple and "Taylor" models
err_base = np.array(target[199:279]) - np.array(target[200:280])
err0 = np.array(pred0[200:280]) - np.array(target[200:280])
err2 = np.array(pred[200:280]) - np.array(target[200:280])

fig = plt.figure(figsize=(15.0, 6.0))
plt.fill_between(date_list[200:280],abs(err0),interpolate=True,facecolor='lightsteelblue',alpha=0.8)
plt.fill_between(date_list[200:280],abs(err2),interpolate=True,facecolor='palegoldenrod',alpha=1)
p1 = plt.plot(date_list[200:280], abs(err0), color='blue',linewidth=2)
p2 = plt.plot(date_list[200:280], abs(err2), color='red',linewidth=2)
p3 = plt.scatter(date_list[200:280], abs(err_base), color='black', marker='_', s=50)
plt.legend(('Single-day','Multi-day','Baseline'))
plt.xlim([date_list[200],date_list[279]])
plt.ylim([0,10])
plt.title('Comparison of errors of single, multi-day and baseline models for CYYZ')
plt.ylabel('absolute error (C)')

fig.autofmt_xdate()
plt.show()

# %%
# using data from one city on multiple days ("Taylor model") ... predict two-days ahead
featureData, target, model_params = Reg.oneCityTaylorModel('CYYZ','2005-01-01','2010-12-31',\
                                                           ['TempMax','dailyTempRange',\
                                                            'PressMax','dailyPressRange',\
                                                            'HumidityMean',\
                                                            'isWesterly','isSoutherly',\
                                                            'isFoggy',\
                                                            'isMorningMinTemp', 'isMorningMaxTemp', \
                                                            'isDaytimeMinPress', 'isDaytimeMaxPress', \
                                                            'isMorningMaxWind'], \
                                                            targetVar='TempMax',lag=2,order=2,scale=True)
# Out:
# R^2: 0.841123626792
# Regression coefficients (scaled, sorted):
#   intercept:	13.2117055327
#   0th deriv of TempMax:	10.3909656881
#   1th deriv of isMorningMinTemp:	-2.84277967044
#   1th deriv of dailyTempRange:	2.58285872587
#   1th deriv of TempMax:	-2.05727362533
#   2th deriv of dailyTempRange:	-1.96460614114
#   2th deriv of isMorningMinTemp:	1.95914397313
#   0th deriv of isMorningMinTemp:	1.53614703746
#   1th deriv of isWesterly:	1.18764144141
#   1th deriv of isSoutherly:	1.18630609046
#   0th deriv of isWesterly:	-1.18530711832
#   1th deriv of PressMax:	1.05034888647
#   0th deriv of dailyPressRange:	0.956060613818
#   2th deriv of TempMax:	0.916482774345
#   0th deriv of isSoutherly:	-0.879798955408
#   2th deriv of isWesterly:	-0.733902978971
#   1th deriv of isDaytimeMaxPress:	0.675753462519
#   2th deriv of PressMax:	-0.639520376099
#   1th deriv of isFoggy:	0.60695570392
#   1th deriv of HumidityMean:	0.596032339189
#   2th deriv of dailyPressRange:	0.590679377581
#   1th deriv of dailyPressRange:	-0.57157297533
#   1th deriv of isMorningMaxWind:	0.556843017247
#   2th deriv of isSoutherly:	-0.554441039561
#   1th deriv of isDaytimeMinPress:	-0.489382525001
#   0th deriv of PressMax:	0.486282915443
#   2th deriv of isFoggy:	-0.46880789889
#   0th deriv of isDaytimeMinPress:	0.436566544566
#   0th deriv of dailyTempRange:	-0.362840286782
#   2th deriv of isMorningMaxWind:	-0.307512971733
#   0th deriv of HumidityMean:	-0.274707644591
#   0th deriv of isDaytimeMaxPress:	-0.27447083063
#   2th deriv of isDaytimeMaxPress:	-0.248185602321
#   2th deriv of isDaytimeMinPress:	0.237096177939
#   2th deriv of HumidityMean:	-0.212053313713
#   1th deriv of isMorningMaxTemp:	-0.182481714905
#   0th deriv of isMorningMaxWind:	-0.179596688175
#   0th deriv of isFoggy:	-0.0739875650779
#   0th deriv of isMorningMaxTemp:	0.0610138717837
#   2th deriv of isMorningMaxTemp:	-0.0413465620341

# %%
date_list, pred, target, model_perf = Reg.oneCityTaylorPredict(model_params, \
                                                               '2011-01-01', '2012-12-31', \
                                                               actual=True)

ax = Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300, showIt=False)
ax.set_title('One-city, multi-day model 2-day ahead prediction for CYYZ')
ax.set_ylabel('Temperature (C)')
plt.show()
# Out:
# R^2_mean:	0.825919977923
# R^2_base:	0.340049862897
# RMSE:		4.5603786193
# RMSE_base:	5.613650096

# %% [markdown]
# ### Multi-city, multi-day model

# %%
# using data from multiple cities on multiple days

# get list of all available stations
import wUUtils as Util
stations = Util.getStationList()
# move target station to front
targStation = 'CYYZ'
stations = [targStation] + [s for s in stations if s != targStation]
# build model
featureData, target, model_params = Reg.multiCityTaylorModel(stations,'2005-01-01','2010-12-31',\
                                                           ['TempMax','dailyTempRange',\
                                                            'PressMax','dailyPressRange',\
                                                            'HumidityMean',\
                                                            'isWesterly','isSoutherly',\
                                                            'isFoggy'], \
                                                            targetVar='TempMax',lag=1,order=1,scale=True,verbose=False)
# Out:
# R^2: 0.968230625716

# %%
# map of average (sum) regression coefficients by station:
import wUMapPlots as Map

stations = model_params['stations']
features = model_params['features']
regr = model_params['regr']
order = model_params['order']

nfeat = len(features)
nstat = len(stations)
sum_coef = []
for i,station in enumerate(stations):
    vals = []
    for jj in range(order):
        start = jj*nstat*nfeat + i*nfeat
        end = jj*nstat*nfeat + (i+1)*nfeat
        vals += [abs(coco) for coco in regr.coef_[start:end]]
    sum_coef.append(sum(vals))

Map.contourPlotStationsOnMap(stations, sum_coef, title='sum of scaled regression coefficients', width_fac=18, height_fac=15)
# Out:
# ('centre at: ', -84.302951814208981, 42.476200103753712)

# %%
# predict
date_list, pred, target, model_perf = Reg.multiCityTaylorPredict(model_params, \
                                                                 '2011-01-01', '2012-12-31', \
                                                                 actual=True)
ax = Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300, showIt=False)
ax.set_title('Multi-city model prediction for CYYZ')
ax.set_ylabel('Temperature (C)')
plt.show()
# Out:
# R^2_mean:	0.943370311096
# R^2_base:	0.638654801965
# RMSE:		2.60304476598

# %%
# Some statistics of this rather decent prediction!
import matplotlib.mlab as mlab

lag = 1

# error of regression model
err = np.array(pred[lag:]) - np.array(target[lag:])
# error of "baseline model" (predicted temp same as temp on prediction day)
err_base = np.array(target[:-lag]) - np.array(target[lag:])

fig = plt.figure(figsize=(10.0, 6.0))
# histogram of day-over-day changes in daily max temperature
n, bins_base, patches = plt.hist(err_base, 30, normed=1, facecolor='blue', alpha=0.6)
# histogram of errors by prediction model
n, bins, patches = plt.hist(err, 30, normed=1, facecolor='green', alpha=0.5)

# add a 'best fit' normal distribution curves
mu = np.mean(err)
mu_base = np.mean(err_base)
sigma = np.std(err)
sigma_base = np.std(err_base)
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=2)
y_base = mlab.normpdf(bins_base, mu_base, sigma_base)
l_base = plt.plot(bins_base, y_base, 'r', linewidth=2)

plt.xlabel('error in predicted maximum Temperature')
plt.title('Baseline (blue): mean = %.3f, sigma = %.2f; Reg (green): mean = %.3f, sigma= %.2f' \
          % (mu_base, sigma_base, mu, sigma))
plt.xlim([-18,18])
plt.grid(True)
plt.show()

# Extreme events:
print("Performance when change from prediction day is larger:\n")
for ii in range(10):
     extreme = [(err[i],err_base[i]) for i in range(len(err)) \
                if (abs(err_base[i]) > ii*sigma_base) & (abs(err_base[i]) < (ii+1)*sigma_base)]
     better = [int(abs(e[0]) < abs(e[1])) for e in extreme]
     print('There were %d %d-sigma events!' % (len(extreme),ii))
     if (len(extreme) > 0):
          print('Regression beats baseline %.1f%% of the time' \
                % (float(100*sum(better)) / float(len(better))))
          rmse = np.sqrt(np.mean([e[1]*e[1] for e in extreme]))
          print('Baseline RMSE : \t%.2f' % rmse)
          rmse = np.sqrt(np.mean([e[0]*e[0] for e in extreme]))
          print('Regression RMSE : \t%.2f\n' % rmse)
     else:
          break
# Out:
# Performance when change from prediction day is larger:
#
# There were 459 0-sigma events!
# Regression beats baseline 55.6% of the time
# Baseline RMSE : 	2.39
# Regression RMSE : 	2.58
#
# There were 151 1-sigma events!
# Regression beats baseline 83.4% of the time
# Baseline RMSE : 	6.13
# Regression RMSE : 	4.70
#
# There were 37 2-sigma events!
# Regression beats baseline 100.0% of the time
# Baseline RMSE : 	10.66
# Regression RMSE : 	6.93
#
# There were 5 3-sigma events!
# Regression beats baseline 100.0% of the time
# Baseline RMSE : 	15.21
# Regression RMSE : 	9.33
#
# There were 0 4-sigma events!

# %%
# compare errors from one-city and multi-city models
err_base = np.array(target[199:279]) - np.array(target[200:280])
err1 = np.array(pred1[200:280]) - np.array(target[200:280])
err2 = np.array(pred[200:280]) - np.array(target[200:280])

fig = plt.figure(figsize=(15.0, 6.0))
plt.fill_between(date_list[200:280],abs(err2),interpolate=True,facecolor='lightsteelblue',alpha=0.8)
plt.fill_between(date_list[200:280],abs(err1),interpolate=True,facecolor='palegoldenrod',alpha=1)
p1 = plt.plot(date_list[200:280], abs(err2), color='blue',linewidth=2)
p2 = plt.plot(date_list[200:280], abs(err1), color='red',linewidth=2)
p3 = plt.scatter(date_list[200:280], abs(err_base), color='black', marker='_', s=50)
plt.legend(('One-city','Multi-city','Baseline'))
plt.xlim([date_list[200],date_list[279]])
plt.ylim([0,10])
plt.title('Comparison of errors of single, multi-day and baseline models for CYYZ')
plt.ylabel('absolute error (C)')

fig.autofmt_xdate()
plt.show()

# %%
# predict something else?  How about maximum SLP

# get list of all available stations
import wUUtils as Util
stations = Util.getStationList()
# move target station to front
targStation = 'CYYZ'
stations = [targStation] + [s for s in stations if s != targStation]

# build model
print('training . . . ')
featureData, target, model_params = Reg.multiCityTaylorModel(stations,'2005-01-01','2010-12-31',\
                                                           ['TempMax','dailyTempRange',\
                                                           'PressMax','dailyPressRange',\
                                                           'HumidityMean',\
                                                           'isWesterly','isSoutherly',\
                                                           'isFoggy'],targetVar='PressMax',lag=1,order=1,scale=True,verbose=False)

# predict
print('testing . . .')
date_list, pred, target, model_perf = Reg.multiCityTaylorPredict(model_params, \
                                                                 '2011-01-01', '2012-12-31', \
                                                                 actual=True)

ax = Reg.plotModelPred(date_list, pred, target, showIt=False)
ax.set_title('Multi-city model prediction for CYYZ')
ax.set_ylabel('Sea-level Pressure (hPa))')
plt.show()

ax = Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300, showIt=False)
ax.set_title('Multi-city model prediction for CYYZ')
ax.set_ylabel('Sea-level Pressure (hPa))')
plt.show()
# Out:
# training . . .
# R^2: 0.879672013307
# testing . . .
# R^2_mean:	0.772853202905
# R^2_base:	0.686404398823
# RMSE:		3.35055762933

# %%
# statistics
lag = 1

# error of regression model
err = np.array(pred[lag:]) - np.array(target[lag:])
# error of "baseline model" (predicted temp same as temp on prediction day)
err_base = np.array(target[:-lag]) - np.array(target[lag:])

fig = plt.figure(figsize=(10.0, 6.0))
# histogram of day-over-day changes in daily max temperature
n, bins_base, patches = plt.hist(err_base, 30, normed=1, facecolor='blue', alpha=0.8)
# histogram of errors by prediction model
n, bins, patches = plt.hist(err, 30, normed=1, facecolor='green', alpha=0.5)

# add a 'best fit' normal distribution curves
mu = np.mean(err)
mu_base = np.mean(err_base)
sigma = np.std(err)
sigma_base = np.std(err_base)
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=2)
y_base = mlab.normpdf(bins_base, mu_base, sigma_base)
l_base = plt.plot(bins_base, y_base, 'r', linewidth=2)

plt.xlabel('error in predicted maximum SLP')
plt.title('Baseline (blue): mean = %.3f, sigma = %.2f; Reg (green): mean = %.3f, sigma= %.2f' \
          % (mu_base, sigma_base, mu, sigma))
plt.xlim([-18,18])
plt.grid(True)
plt.show()

# Extreme events:
print("Performance when change from prediction day is larger:\n")
for ii in range(10):
     extreme = [(err[i],err_base[i]) for i in range(len(err)) \
                if (abs(err_base[i]) > ii*sigma_base) & (abs(err_base[i]) < (ii+1)*sigma_base)]
     better = [int(abs(e[0]) < abs(e[1])) for e in extreme]
     print('There were %d %d-sigma events!' % (len(extreme),ii))
     if (len(extreme) > 0):
          print('Regression beats baseline %.1f%% of the time' \
                % (float(100*sum(better)) / float(len(better))))
          rmse = np.sqrt(np.mean([e[1]*e[1] for e in extreme]))
          print('Baseline RMSE : \t%.2f' % rmse)
          rmse = np.sqrt(np.mean([e[0]*e[0] for e in extreme]))
          print('Regression RMSE : \t%.2f\n' % rmse)
     else:
          break
# Out:
# Performance when change from prediction day is larger:
#
# There were 526 0-sigma events!
# Regression beats baseline 57.6% of the time
# Baseline RMSE : 	2.94
# Regression RMSE : 	2.72
#
# There were 147 1-sigma events!
# Regression beats baseline 97.3% of the time
# Baseline RMSE : 	8.44
# Regression RMSE : 	3.96
#
# There were 33 2-sigma events!
# Regression beats baseline 100.0% of the time
# Baseline RMSE : 	14.52
# Regression RMSE : 	5.54
#
# There were 9 3-sigma events!
# Regression beats baseline 100.0% of the time
# Baseline RMSE : 	19.74
# Regression RMSE : 	8.55
#
# There were 1 4-sigma events!
# Regression beats baseline 100.0% of the time
# Baseline RMSE : 	25.10
# Regression RMSE : 	14.24
#
# There were 0 5-sigma events!

# %% [markdown]
# ### Advection model

# %%
# using data from multiple cities but only components advected towards target city
# get list of all available stations
import wUUtils as Util
stations = Util.getStationList()
# move target station to front
targStation = 'CYYZ'
stations = [targStation] + [s for s in stations if s != targStation]
# build model
featureData, target, model_params = Reg.advectionTaylorModel(stations,'2005-01-01','2010-12-31',\
                                                             ['TempMax','PressMax'],targetVar='TempMax',\
                                                             lag=1,order=1,verbose=False)
# Out:
# R^2: 0.9335430849

# %%
# predict
date_list, pred, target, model_perf = Reg.advectionTaylorPredict(model_params, \
                                                                 '2011-01-01', '2012-12-31', \
                                                                 actual=True)
ax = Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300, showIt=False)
ax.set_title('Multi-city "advection"-model prediction for CYYZ')
ax.set_ylabel('Temperature (C)')
plt.show()
# Out:
# R^2_mean:	0.925849311217
# R^2_base:	0.526856038922
# RMSE:		2.978634009

# %% [markdown]
# ### Predictability by station

# %%
# comparison of performance by station
# one-station Taylor model:
stations = Util.getStationList()
reload(Reg)
perfList = Reg.compareStationsOneCity(stations, \
                                      '2005-01-01', '2010-12-31', '2011-01-01', '2012-12-31', \
                                      ['TempMax','dailyTempRange',\
                                       'PressMax','dailyPressRange',\
                                       'HumidityMean',\
                                       'isWesterly','isSoutherly',\
                                       'isFoggy',\
                                       'isMorningMinTemp', 'isMorningMaxTemp', \
                                       'isDaytimeMinPress', 'isDaytimeMaxPress', \
                                       'isMorningMaxWind'], \
                                       targetVar='TempMax', \
                                       lag=1, order=1)
# Out:
# CYGK:
# R^2: 0.90550118833
# R^2_mean:	0.88263315656
# R^2_base:	0.289214780998
# RMSE:		3.6819281503
# RMSE_base:	4.36723051051
#
# CYOW:
# R^2: 0.909093101285
# R^2_mean:	0.895790802547
# R^2_base:	0.267275984365
# RMSE:		4.04725232927
# RMSE_base:	4.72813718151
#
# CYQT:
# R^2: 0.892702871412
# R^2_mean:	0.890256777202
# R^2_base:	0.1825291784
# RMSE:		4.01645026815
# RMSE_base:	4.44228342524
#
# CYSB:
# R^2: 0.910314578163
# R^2_mean:	0.906668826089
# R^2_base:	0.33394034285
# RMSE:		3.82736778307
# RMSE_base:	4.68968456183
#
# CYUL:
# R^2: 0.920275988117
# R^2_mean:	0.910778738748
# R^2_base:	0.302881448745
# RMSE:		3.57244142043
# RMSE_base:	4.27869959605
#
# CYWG:
# R^2: 0.926633236858
# R^2_mean:	0.913284008945
# R^2_base:	0.257906672303
# RMSE:		4.2865125773
# RMSE_base:	4.97593660835
#
# CYYZ:
# R^2: 0.909185473932
# R^2_mean:	0.893755915802
# R^2_base:	0.322073096508
# RMSE:		3.56543010962
# RMSE_base:	4.33032500832
#
# KBNA:
# R^2: 0.867992024796
# R^2_mean:	0.847433935
# R^2_base:	0.232403315098
# RMSE:		3.71768810066
# RMSE_base:	4.24332607592
#
# KBOS:
# R^2: 0.844233466175
# R^2_mean:	0.845112434693
# R^2_base:	0.286094712758
# RMSE:		3.75746060662
# RMSE_base:	4.4470717543
#
# KBUF:
# R^2: 0.898240444567
# R^2_mean:	0.886671286397
# R^2_base:	0.303893105264
# RMSE:		3.63715619491
# RMSE_base:	4.35937254014
#
# KCLE:
# R^2: 0.891484237426
# R^2_mean:	0.86373395424
# R^2_base:	0.288143318958
# RMSE:		3.97462729402
# RMSE_base:	4.71085924088
#
# KCLT:
# R^2: 0.855829624923
# R^2_mean:	0.851123332875
# R^2_base:	0.225248885479
# RMSE:		3.2105486344
# RMSE_base:	3.64752391727
#
# KCVG:
# R^2: 0.893803003147
# R^2_mean:	0.872101644573
# R^2_base:	0.258219431354
# RMSE:		3.74791564992
# RMSE_base:	4.35163120008
#
# KDSM:
# R^2: 0.90112622482
# R^2_mean:	0.878024080955
# R^2_base:	0.258226445795
# RMSE:		4.23039579159
# RMSE_base:	4.91185263381
#
# KDTW:
# R^2: 0.90816634403
# R^2_mean:	0.895717153272
# R^2_base:	0.279624108554
# RMSE:		3.65256526944
# RMSE_base:	4.30346623938
#
# KGRB:
# R^2: 0.91677767545
# R^2_mean:	0.910168850593
# R^2_base:	0.231653256014
# RMSE:		3.54361388927
# RMSE_base:	4.0426651221
#
# KIAD:
# R^2: 0.860290957711
# R^2_mean:	0.856636461363
# R^2_base:	0.281408358861
# RMSE:		3.70062185237
# RMSE_base:	4.36549634051
#
# KIND:
# R^2: 0.898969223233
# R^2_mean:	0.886128102259
# R^2_base:	0.273991274209
# RMSE:		3.74485368575
# RMSE_base:	4.39505115133
#
# KJFK:
# R^2: 0.89048186033
# R^2_mean:	0.87851824336
# R^2_base:	0.246257032245
# RMSE:		3.21393857439
# RMSE_base:	3.70191067709
#
# KMCI:
# R^2: 0.870405235172
# R^2_mean:	0.864477327747
# R^2_base:	0.261087268618
# RMSE:		4.23430003471
# RMSE_base:	4.92589390132
#
# KMEM:
# R^2: 0.871027327252
# R^2_mean:	0.870116221423
# R^2_base:	0.293641238965
# RMSE:		3.37264157642
# RMSE_base:	4.01289246037
#
# KMKE:
# R^2: 0.895408510453
# R^2_mean:	0.872629876043
# R^2_base:	0.309549961848
# RMSE:		3.96525323797
# RMSE_base:	4.77204795669
#
# KMSP:
# R^2: 0.924118619081
# R^2_mean:	0.906325469323
# R^2_base:	0.260939289302
# RMSE:		3.9194788732
# RMSE_base:	4.55919607622
#
# KOKC:
# R^2: 0.8400408145
# R^2_mean:	0.862752668127
# R^2_base:	0.268745519114
# RMSE:		4.00054270025
# RMSE_base:	4.67826307562
#
# KORD:
# R^2: 0.901142139705
# R^2_mean:	0.881268660177
# R^2_base:	0.26381136338
# RMSE:		3.95075965062
# RMSE_base:	4.60453792984
#
# KPHL:
# R^2: 0.888411083698
# R^2_mean:	0.866100893437
# R^2_base:	0.218228652739
# RMSE:		3.59935494961
# RMSE_base:	4.07084720693
#
# KPIT:
# R^2: 0.888502782118
# R^2_mean:	0.86814177722
# R^2_base:	0.315246201364
# RMSE:		3.81759618108
# RMSE_base:	4.61341754009
#
# KROC:
# R^2: 0.891056987397
# R^2_mean:	0.865834826244
# R^2_base:	0.288967411001
# RMSE:		3.94513915919
# RMSE_base:	4.67861785366
#
# KSTL:
# R^2: 0.867398042606
# R^2_mean:	0.86505683465
# R^2_base:	0.283945571398
# RMSE:		4.08211911721
# RMSE_base:	4.82405950094

# %%
import wUMapPlots as Map
reload(Map)
stations = [a['station'] for a in perfList]
R2 = [a['R2_base'] for a in perfList]
RMSE = [a['RMSE'] for a in perfList]
Map.contourPlotStationsOnMap(stations, R2, title='R2, one-city models', width_fac=18, height_fac=15)
Map.contourPlotStationsOnMap(stations, RMSE, title='RMSE, one-city models', width_fac=18, height_fac=15)
# Out:
# ('centre at: ', -84.302951814208981, 42.476200103753712)
# ('centre at: ', -84.302951814208981, 42.476200103753712)

# %%
# multi-station Taylor model:
stations = Util.getStationList()
perfList = Reg.compareStationsMultiCity(stations, \
                                        '2005-01-01', '2010-12-31', '2011-01-01', '2012-12-31', \
                                        ['TempMax','dailyTempRange',\
                                        'PressMax','dailyPressRange',\
                                        'HumidityMean','isWesterly','isSoutherly',\
                                        'isFoggy'], targetVar='TempMax', \
                                        lag=1, order=1)
# Out:
# CYGK:
# R^2: 0.959248985196
# R^2_mean:	0.925017880028
# R^2_base:	0.545900860893
# RMSE:		2.94294031699
#
# CYOW:
# R^2: 0.96438310314
# R^2_mean:	0.938315108788
# R^2_base:	0.566276276011
# RMSE:		3.11384261259
#
# CYQT:
# R^2: 0.947406272858
# R^2_mean:	0.910146634161
# R^2_base:	0.33068755479
# RMSE:		3.63429949717
#
# CYSB:
# R^2: 0.959147971441
# R^2_mean:	0.931612369569
# R^2_base:	0.51195040446
# RMSE:		3.27623926339
#
# CYUL:
# R^2: 0.967513748042
# R^2_mean:	0.94263021044
# R^2_base:	0.551748719729
# RMSE:		2.86465657982
#
# CYWG:
# R^2: 0.94463262547
# R^2_mean:	0.906890995865
# R^2_base:	0.203196897406
# RMSE:		4.4417115057
#
# CYYZ:
# R^2: 0.968230625716
# R^2_mean:	0.943370311096
# R^2_base:	0.638654801965
# RMSE:		2.60304476598
#
# KBNA:
# R^2: 0.953942507409
# R^2_mean:	0.90494877831
# R^2_base:	0.521774369254
# RMSE:		2.93442375994
#
# KBOS:
# R^2: 0.929002574996
# R^2_mean:	0.893464953333
# R^2_base:	0.508960367854
# RMSE:		3.11625084875
#
# KBUF:
# R^2: 0.967289760892
# R^2_mean:	0.942884942977
# R^2_base:	0.649178185098
# RMSE:		2.58206564725
#
# KCLE:
# R^2: 0.964395051606
# R^2_mean:	0.934586729921
# R^2_base:	0.658279705155
# RMSE:		2.75381977369
#
# KCLT:
# R^2: 0.936493473289
# R^2_mean:	0.904113562968
# R^2_base:	0.501008953299
# RMSE:		2.57658530118
#
# KCVG:
# R^2: 0.96304138704
# R^2_mean:	0.932703867386
# R^2_base:	0.609698159518
# RMSE:		2.71864425044
#
# KDSM:
# R^2: 0.948223848042
# R^2_mean:	0.895039077652
# R^2_base:	0.361699940181
# RMSE:		3.92425997726
#
# KDTW:
# R^2: 0.967996928652
# R^2_mean:	0.940989141954
# R^2_base:	0.592358659132
# RMSE:		2.74762532737
#
# KGRB:
# R^2: 0.965967094819
# R^2_mean:	0.936755395629
# R^2_base:	0.459054168137
# RMSE:		2.9733405725
#
# KIAD:
# R^2: 0.952689067234
# R^2_mean:	0.9127662234
# R^2_base:	0.562751706009
# RMSE:		2.88667366598
#
# KIND:
# R^2: 0.963550053657
# R^2_mean:	0.941506406795
# R^2_base:	0.627064623391
# RMSE:		2.68398896015
#
# KJFK:
# R^2: 0.954424945496
# R^2_mean:	0.917668587322
# R^2_base:	0.489168373527
# RMSE:		2.64584759293
#
# KMCI:
# R^2: 0.933765518439
# R^2_mean:	0.88114965688
# R^2_base:	0.351990112053
# RMSE:		3.96529835404
#
# KMEM:
# R^2: 0.948628100849
# R^2_mean:	0.902723203275
# R^2_base:	0.470970752739
# RMSE:		2.91875312383
#
# KMKE:
# R^2: 0.955712437583
# R^2_mean:	0.91514802377
# R^2_base:	0.540033028112
# RMSE:		3.23644419876
#
# KMSP:
# R^2: 0.959529429638
# R^2_mean:	0.922332169874
# R^2_base:	0.387226802031
# RMSE:		3.56893099458
#
# KOKC:
# R^2: 0.904246281545
# R^2_mean:	0.86263808571
# R^2_base:	0.268135023416
# RMSE:		4.00221229998
#
# KORD:
# R^2: 0.962230823541
# R^2_mean:	0.920914442461
# R^2_base:	0.509633354865
# RMSE:		3.22438220499
#
# KPHL:
# R^2: 0.9595267441
# R^2_mean:	0.920755611994
# R^2_base:	0.537330804029
# RMSE:		2.7689817597
#
# KPIT:
# R^2: 0.963467945938
# R^2_mean:	0.931769551003
# R^2_base:	0.645672009312
# RMSE:		2.74615782593
#
# KROC:
# R^2: 0.966312001671
# R^2_mean:	0.937556163656
# R^2_base:	0.669067602418
# RMSE:		2.69145558036
#
# KSTL:
# R^2: 0.950707099164
# R^2_mean:	0.908523413524
# R^2_base:	0.514594053804
# RMSE:		3.36097437962

# %%
stations = [a['station'] for a in perfList]
R2 = [a['R2_base'] for a in perfList]
RMSE = [a['RMSE'] for a in perfList]
Map.contourPlotStationsOnMap(stations, R2, title='R2, multi-city models', width_fac=18, height_fac=15)
Map.contourPlotStationsOnMap(stations, RMSE, title='RMSE, multi-city models', width_fac=18, height_fac=15)
# Out:
# ('centre at: ', -84.302951814208981, 42.476200103753712)
# ('centre at: ', -84.302951814208981, 42.476200103753712)

# %% [markdown]
# ### Truncated PCA model

# %%
# PCA models
# using data from multiple cities on multiple days

# get list of all available stations
import wUUtils as Util
stations = Util.getStationList()
# move target station to front
targStation = 'CYYZ'
stations = [targStation] + [s for s in stations if s != targStation]
# build model
featureData, target, model_params = Reg.pcaTaylorModel(stations,'2005-01-01','2010-12-31',\
                                                           ['TempMax','dailyTempRange','PressMax','dailyPressRange',\
                                                            'HumidityMean', \
                                                            'isSoutherly','isWesterly','isFoggy'], \
                                                           ncomp=[8, 5, 8, 5, 5, 5, 5, 5], \
                                                           targetVar='TempMax',lag=1,order=1,verbose=False)
# Out:
# R^2: 0.958017604998
# C:\Python27\lib\site-packages\sklearn\utils\validation.py:498: UserWarning: StandardScaler assumes floating point values as input, got int32
#   "got %s" % (estimator, X.dtype))

# %%
# predict
reload(Reg)
date_list, pred, target, model_perf = Reg.pcaTaylorPredict(model_params, \
                                                           '2011-01-01', '2012-12-31', \
                                                           actual=True)
Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300)
# Out:
# R^2_mean:	0.94627510374
# R^2_base:	0.657189830032
# RMSE:		2.53540499641

# %%
# map regression coefficients back to station-space
regr = model_params['regr']
ncomp = model_params['transform_params']['ncomp']
order = model_params['order']
features = model_params['features']
pcas = model_params['transform_params']['pcas']

nfeat = len(features)
station_coefs = []
for jj in range(order+1):
    for ifeat, feature in enumerate(features):
        start = jj*sum(ncomp) + sum(ncomp[:ifeat])
        end = start + ncomp[ifeat]
        station_coefs.append(pcas[ifeat].inverse_transform(regr.coef_[start:end]))
        
Map.contourPlotStationsOnMap(stations, station_coefs[0], title='Temperature Coefficients', width_fac=18, height_fac=15)
Map.contourPlotStationsOnMap(stations, station_coefs[1], title='Temperature Range Coefficients', width_fac=18, height_fac=15)
Map.contourPlotStationsOnMap(stations, station_coefs[8], title='Temperature Tendency Coefficients', width_fac=18, height_fac=15)

Map.contourPlotStationsOnMap(stations, station_coefs[2], title='Pressure Coefficients', width_fac=18, height_fac=15)
Map.contourPlotStationsOnMap(stations, station_coefs[7], title='Fogginess Coefficients', width_fac=18, height_fac=15)
# Out:
# ('centre at: ', -84.302951814208981, 42.476200103753712)
# ('centre at: ', -84.302951814208981, 42.476200103753712)
# ('centre at: ', -84.302951814208981, 42.476200103753712)
# ('centre at: ', -84.302951814208981, 42.476200103753712)
# ('centre at: ', -84.302951814208981, 42.476200103753712)

# %%
# two days ahead!
# build model
featureData, target, model_params = Reg.pcaTaylorModel(stations,'2005-01-01','2010-12-31',\
                                                           ['TempMax','dailyTempRange','PressMax','dailyPressRange',\
                                                            'HumidityMean', \
                                                            'isSoutherly','isWesterly','isFoggy'], \
                                                           ncomp=[8, 5, 8, 5, 5, 5, 5, 5], \
                                                           targetVar='TempMax',lag=2,order=1,verbose=False)
# predict
date_list, pred, target, model_perf = Reg.pcaTaylorPredict(model_params, \
                                                           '2011-01-01', '2012-12-31', \
                                                           actual=True)
Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300)
# Out:
# R^2: 0.913346660301
# R^2_mean:	0.901890188958
# R^2_base:	0.627317925444
# RMSE:		3.42464932192

# %%
# model with only one PC per feature!!
# build model
print('training . . .')
featureData, target, model_params = Reg.pcaTaylorModel(stations,'2005-01-01','2010-12-31',\
                                                           ['TempMax','dailyTempRange','PressMax','dailyPressRange',\
                                                            'HumidityMean', \
                                                            'isSoutherly','isWesterly','isFoggy'], \
                                                           ncomp=[1, 1, 1, 1, 1, 1, 1, 1], \
                                                           targetVar='TempMax',lag=1,order=1,verbose=False)
print('testing . . .')
date_list, pred, target, model_perf = Reg.pcaTaylorPredict(model_params, \
                                                           '2011-01-01', '2012-12-31', \
                                                           actual=True)
Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300)
# Out:
# training . . .
# R^2: 0.933996117759
# testing . . .
# R^2_mean:	0.928990907351
# R^2_base:	0.546902073066
# RMSE:		2.91485214838

# %% [markdown]
# ### Truncated PCA model with smoothing of training data

# %%
reload(Reg)
# build model
print('training . . .')
featureData, target, model_params = Reg.pcaTaylorModel(stations,'2005-01-01','2010-12-31',\
                                                           ['TempMax','dailyTempRange','PressMax','dailyPressRange',\
                                                            'HumidityMean', \
                                                            'isSoutherly','isWesterly','isFoggy'], \
                                                           ncomp=[29, 1, 1, 1, 1, 1, 1, 1], \
                                                           targetVar='TempMax',lag=1,order=1, \
                                                           smooth_window=3, verbose=False)
print('testing . . .')
date_list, pred, target, model_perf = Reg.pcaTaylorPredict(model_params, \
                                                           '2011-01-01', '2012-12-31', \
                                                           actual=True)
Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300)
# Out:
# training . . .
# R^2: 0.97555964202
# testing . . .
# R^2_mean:	0.926902633108
# R^2_base:	0.533577121354
# RMSE:		2.95740236348

# %% [markdown]
# ### Multi-city, multi-day model with interaction terms

# %%
# using data from multiple cities on multiple days ... with interactions
reload(Reg)
# get list of all available stations
import wUUtils as Util
stations = Util.getStationList()
# move target station to front
targStation = 'CYYZ'
stations = [targStation] + [s for s in stations if s != targStation]
# build model
featureData, target, model_params = Reg.multiCityInteractionModel(stations,'2005-01-01','2010-12-31',\
                                                                  ['TempMax','dailyTempRange', \
                                                                   'TempMax:WindMeanX','TempMax:WindMeanY', \
                                                                   'TempMax:isFoggy',\
                                                                   'isWesterly','isSoutherly',\
                                                                   'isFoggy', \
                                                                   'PressMax','dailyPressRange', \
                                                                   'HumidityMean'], \
                                                                  targetVar='TempMax',lag=1,order=1,scale=True,verbose=False)
# Out:
# R^2: 0.972782505819

# %%
# predict
date_list, pred, target, model_perf = Reg.multiCityInteractionPredict(model_params, \
                                                                      '2011-01-01', '2012-12-31', \
                                                                      actual=True)

Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300)
# Out:
# R^2_mean:	0.939889630203
# R^2_base:	0.616445120954
# RMSE:		2.68184855186

# %% [markdown]
# ### Multi-model average

# %%
# multimodel average
pred_list = []
# interactions . . .
print('\nModel with interactions . . .')
featureData, target, model_params = Reg.multiCityInteractionModel(stations,'2005-01-01','2010-12-31',\
                                                                  ['TempMax','dailyTempRange', \
                                                                   'TempMax:WindMeanX','TempMax:WindMeanY', \
                                                                   'TempMax:isFoggy',\
                                                                   'PressMax','dailyPressRange', \
                                                                   'HumidityMean'], \
                                                                  targetVar='TempMax',lag=1,order=1,scale=True,verbose=False)
date_list, pred, target, model_perf_inter = Reg.multiCityInteractionPredict(model_params, \
                                                                            '2011-01-01', '2012-12-31', \
                                                                            actual=True)
pred_list.append(pred)

# no interactions
print('\nModel without interactions . . .')
featureData, target, model_params = Reg.multiCityInteractionModel(stations,'2005-01-01','2010-12-31',\
                                                                  ['TempMax','dailyTempRange', \
                                                                   'isWesterly','isSoutherly',\
                                                                   'isFoggy', \
                                                                   'PressMax','dailyPressRange', \
                                                                   'HumidityMean'], \
                                                                  targetVar='TempMax',lag=1,order=1,scale=True,verbose=False)
date_list, pred, target, model_perf = Reg.multiCityInteractionPredict(model_params, \
                                                                      '2011-01-01', '2012-12-31', \
                                                                      actual=True)
pred_list.append(pred)

# truncated PCA
print('\nModel with truncated PCA . . .')
featureData, target, model_params = Reg.pcaTaylorModel(stations,'2005-01-01','2010-12-31',\
                                                       ['TempMax','dailyTempRange','PressMax','dailyPressRange',\
                                                        'HumidityMean', \
                                                        'isSoutherly','isWesterly','isFoggy'], \
                                                        ncomp=[8, 5, 8, 5, 5, 5, 5, 5], \
                                                        targetVar='TempMax',lag=1,order=1,verbose=False)
date_list, pred, target, model_perf = Reg.pcaTaylorPredict(model_params, \
                                                           '2011-01-01', '2012-12-31', \
                                                           actual=True)
pred_list.append(pred)

# advection
print('\nModel with advection components . . .')
featureData, target, model_params = Reg.advectionTaylorModel(stations,'2005-01-01','2010-12-31',\
                                                             ['TempMax','PressMax'],targetVar='TempMax',\
                                                             lag=1,order=1,verbose=False)
date_list, pred, target, model_perf = Reg.advectionTaylorPredict(model_params, \
                                                                 '2011-01-01', '2012-12-31', \
                                                                 actual=True)
pred_list.append(pred)
# Out:
# Model with interactions . . .
# R^2: 0.968891086551
# R^2_mean:	0.94402338173
# R^2_base:	0.642821943657
# RMSE:		2.58799169274
#
# Model without interactions . . .
# R^2: 0.968230625716
# R^2_mean:	0.943370311096
# R^2_base:	0.638654801965
# RMSE:		2.60304476598
#
# Model with truncated PCA . . .
# R^2: 0.958017604998
# R^2_mean:	0.94627510374
# R^2_base:	0.657189830032
# RMSE:		2.53540499641
#
# Model with advection components . . .
# R^2: 0.9335430849
# R^2_mean:	0.925849311217
# R^2_base:	0.526856038922
# RMSE:		2.978634009

# %%
# performance of the averaged model
import numpy as np
pred_mean = [np.mean([p[ii] for p in pred_list]) for ii in range(len(date_list))]

err = np.array(pred_mean) - np.array(target)
rmse = np.sqrt(mean(err**2))
print('RMSE of average model: ' + str(rmse))
Reg.plotModelPred(date_list, pred_mean, target, startIndex=200, endIndex=300)
# Out:
# RMSE of average model: 2.39140601629

# %%
# Statistics of boffo-looking average prediction!
import matplotlib.mlab as mlab

lag = 1

# error of regression model
err = np.array(pred_mean[lag:]) - np.array(target[lag:])
# error of "baseline model" (predicted temp same as temp on prediction day)
err_base = np.array(target[:-lag]) - np.array(target[lag:])

fig = plt.figure(figsize=(10.0, 6.0))
# histogram of day-over-day changes in daily max temperature
n, bins_base, patches = plt.hist(err_base, 30, normed=1, facecolor='blue', alpha=0.8)
# histogram of errors by prediction model
n, bins, patches = plt.hist(err, 30, normed=1, facecolor='green', alpha=0.5)

# add a 'best fit' normal distribution curves
mu = np.mean(err)
mu_base = np.mean(err_base)
sigma = np.std(err)
sigma_base = np.std(err_base)
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=2)
y_base = mlab.normpdf(bins_base, mu_base, sigma_base)
l_base = plt.plot(bins_base, y_base, 'r', linewidth=2)

plt.xlabel('error in predicted maximum Temperature')
plt.title('Baseline (blue): mean = %.3f, sigma = %.2f; Reg (green): mean = %.3f, sigma= %.2f' \
          % (mu_base, sigma_base, mu, sigma))
plt.xlim([-18,18])
plt.grid(True)
plt.show()

# Extreme events:
print("Performance when change from prediction day is larger:\n")
for ii in range(10):
     extreme = [(err[i],err_base[i]) for i in range(len(err)) \
                if (abs(err_base[i]) > ii*sigma_base) & (abs(err_base[i]) < (ii+1)*sigma_base)]
     better = [int(abs(e[0]) < abs(e[1])) for e in extreme]
     print('There were %d %d-sigma events!' % (len(extreme),ii))
     if (len(extreme) > 0):
          print('Regression beats baseline %.1f%% of the time' \
                % (float(100*sum(better)) / float(len(better))))
          rmse = np.sqrt(np.mean([e[1]*e[1] for e in extreme]))
          print('Baseline RMSE : \t%.2f' % rmse)
          rmse = np.sqrt(np.mean([e[0]*e[0] for e in extreme]))
          print('Regression RMSE : \t%.2f\n' % rmse)
     else:
          break
# Out:
# Performance when change from prediction day is larger:
#
# There were 460 0-sigma events!
# Regression beats baseline 67.8% of the time
# Baseline RMSE : 	2.39
# Regression RMSE : 	1.96
#
# There were 151 1-sigma events!
# Regression beats baseline 97.4% of the time
# Baseline RMSE : 	6.13
# Regression RMSE : 	3.07
#
# There were 31 2-sigma events!
# Regression beats baseline 100.0% of the time
# Baseline RMSE : 	10.15
# Regression RMSE : 	3.47
#
# There were 11 3-sigma events!
# Regression beats baseline 100.0% of the time
# Baseline RMSE : 	14.05
# Regression RMSE : 	5.61
#
# There were 0 4-sigma events!
