# %% [markdown]
# ## Transform data using PCA

# %%
cd I:/wpwp/Scraping
# Out:
# I:\wpwp\Scraping

# %%
cd D:/mfruman/Documents/wpwp/Python
# Out:
# D:\mfruman\Documents\wpwp\Python

# %%
pylab.rcParams['figure.figsize'] = (6.0, 5.0)

# %%
import wUPCA as PCA
import wUMapPlots as Map
import wUUtils as Util

# %%
stations = Util.getStationList()
features = ['TempMax', 'HumidityMean', 'PressMax']
ncomp = [29, 11, 5]

pcaData, transform_params = PCA.pcaConvert(stations, features, '2005-01-01', '2010-12-31', ncomp)
print('number of features: %d\n' % len(pcaData))
for ii in range(len(pcaData)):
     print('number of PC in feature %s: %d, number of values: %d' % (features[ii], len(pcaData[ii]), len(pcaData[ii][0])))
     print('  shape of each PC rotation: %s\n' % str(transform_params['pcas'][ii].components_.shape))
# Out:
# number of features: 3
#
# number of PC in feature TempMax: 29, number of values: 2191
#   shape of each PC rotation: (29, 29)
#
# number of PC in feature HumidityMean: 11, number of values: 2191
#   shape of each PC rotation: (11, 29)
#
# number of PC in feature PressMax: 5, number of values: 2191
#   shape of each PC rotation: (5, 29)

# %%
import matplotlib.pyplot as plt

vrncs0 = transform_params['pcas'][0].explained_variance_ratio_
vrncs1 = transform_params['pcas'][1].explained_variance_ratio_
vrncs2 = transform_params['pcas'][2].explained_variance_ratio_

# time series of leading three PC of each variable
date_list = Util.dateList('2005-01-01','2010-12-31')
fig, (axT, axH, axP) = plt.subplots(3, sharex=True)
fig.set_figheight(14.0)
fig.set_figwidth(14.0)

axT.plot(date_list,pcaData[0][0],color='blue')
axT.plot(date_list,pcaData[0][1],color='red')
axT.plot(date_list,pcaData[0][2],color='black')
axT.set_ylim([-13,10])
axT.legend(['%.3f' % vrncs0[0],'%.3f' % vrncs0[1],'%.3f' % vrncs0[2]],ncol=3)
axT.set_title('Time-series of leading 3 TempMax PC', size=14)
axT.grid(True)

axH.plot(date_list,pcaData[1][0],color='blue')
axH.plot(date_list,pcaData[1][1],color='red')
axH.plot(date_list,pcaData[1][2],color='black')
axH.set_ylim([-12,12])
axH.legend(['%.3f' % vrncs1[0],'%.3f' % vrncs1[1],'%.3f' % vrncs1[2]],ncol=3)
axH.set_title('Time-series of leading 3 HumidityMean PC', size=14)
axH.grid(True)

axP.plot(date_list,pcaData[2][0],color='blue')
axP.plot(date_list,pcaData[2][1],color='red')
axP.plot(date_list,pcaData[2][2],color='black')
axP.set_ylim([-12,12])
axP.legend(['%.3f' % vrncs2[0],'%.3f' % vrncs2[1],'%.3f' % vrncs2[2]],ncol=3)
axP.set_title('Time-series of leading 3 PressMax PC', size=14)
axP.grid(True)

fig.autofmt_xdate()

# %%
# variance explained by PC
print('Temp PC: \t' + str(transform_params['pcas'][0].explained_variance_ratio_))
print('Humidity PC: \t' + str(transform_params['pcas'][1].explained_variance_ratio_))

# components of the first 5 temperature PC
TempPC = transform_params['pcas'][0].components_
print('station\t PC1 \t\t PC2 \t\t PC3 \t\t PC4 \t\t PC5')
for ii in range(len(stations)):
    print('%s \t %f \t %f \t %f \t %f \t %f' \
             % (stations[ii] , TempPC[0,ii], TempPC[1,ii], TempPC[2,ii], TempPC[3,ii], TempPC[4,ii]))
# Out:
# Temp PC: 	[  8.95539741e-01   3.19766858e-02   1.91134002e-02   1.15046541e-02
#    7.60766842e-03   5.74935724e-03   3.89531448e-03   3.63151396e-03
#    2.94317330e-03   2.20916702e-03   1.82593818e-03   1.74158978e-03
#    1.56757355e-03   1.34596594e-03   1.26436535e-03   1.01908489e-03
#    9.51773724e-04   8.93889946e-04   8.26178504e-04   7.31333520e-04
#    6.59441556e-04   5.55735498e-04   4.97657356e-04   4.19628722e-04
#    3.84910777e-04   3.16275736e-04   3.04234408e-04   2.77740156e-04
#    2.46006577e-04]
# Humidity PC: 	[ 0.36120483  0.14006074  0.10230866  0.06235029  0.05208045  0.0400171
#   0.03204111  0.02722689  0.01994608  0.01828911  0.01682357]
# station	 PC1 		 PC2 		 PC3 		 PC4 		 PC5
# CYGK 	 0.188443 	 -0.145126 	 0.172385 	 -0.001845 	 0.156801
# CYOW 	 0.187669 	 -0.154747 	 0.222577 	 0.005724 	 0.181317
# CYQT 	 0.182842 	 0.162610 	 0.280177 	 -0.062569 	 -0.303850
# CYSB 	 0.188068 	 -0.022718 	 0.232952 	 0.103815 	 0.033499
# CYUL 	 0.186812 	 -0.173227 	 0.217997 	 -0.058543 	 0.175640
# CYWG 	 0.176633 	 0.217018 	 0.297516 	 -0.246833 	 -0.366606
# CYYZ 	 0.190928 	 -0.133037 	 0.122714 	 0.115302 	 0.117007
# KBNA 	 0.184634 	 0.063369 	 -0.353322 	 0.014257 	 -0.091324
# KBOS 	 0.177554 	 -0.269776 	 0.067349 	 -0.356562 	 0.102241
# KBUF 	 0.189385 	 -0.170214 	 0.050143 	 0.199252 	 0.124463
# KCLE 	 0.190090 	 -0.113309 	 -0.078525 	 0.277326 	 0.009524
# KCLT 	 0.175991 	 -0.115545 	 -0.342190 	 -0.280064 	 -0.327640
# KCVG 	 0.189382 	 0.003525 	 -0.236547 	 0.185480 	 -0.117961
# KDSM 	 0.183999 	 0.290637 	 0.070356 	 -0.060930 	 0.018989
# KDTW 	 0.192450 	 -0.039069 	 0.009671 	 0.211374 	 -0.014805
# KGRB 	 0.189748 	 0.134321 	 0.159631 	 0.105806 	 -0.145900
# KIAD 	 0.184822 	 -0.219016 	 -0.169543 	 -0.185421 	 -0.132798
# KIND 	 0.190185 	 0.065507 	 -0.188331 	 0.200110 	 -0.070512
# KJFK 	 0.184513 	 -0.220187 	 0.003983 	 -0.319132 	 -0.033599
# KMCI 	 0.179917 	 0.335220 	 -0.049256 	 -0.152244 	 0.267341
# KMEM 	 0.182924 	 0.136152 	 -0.326989 	 -0.061123 	 0.054269
# KMKE 	 0.189473 	 0.113771 	 0.062864 	 0.203975 	 -0.056876
# KMSP 	 0.185129 	 0.237762 	 0.193233 	 -0.060101 	 -0.213292
# KOKC 	 0.172069 	 0.320846 	 -0.103919 	 -0.288984 	 0.541542
# KORD 	 0.190624 	 0.135184 	 0.007411 	 0.198648 	 -0.059252
# KPHL 	 0.185550 	 -0.250610 	 -0.071577 	 -0.230740 	 -0.053301
# KPIT 	 0.188545 	 -0.161772 	 -0.144957 	 0.190259 	 -0.071154
# KROC 	 0.188957 	 -0.198896 	 0.071445 	 0.158484 	 0.157946
# KSTL 	 0.185902 	 0.215276 	 -0.195679 	 0.072903 	 0.127029

# %%
# plot PC on map
reload(Map)

# get longitude and latitude of stations 
lon, lat = Util.getStationLonLat(stations)

# get variance explained by each PC
vrncs = transform_params['pcas'][0].explained_variance_ratio_

# first PC is very homogeneous so pattern not interesting
Map.contourPlotOnMap(lon, lat, TempPC[0] , width_fac=18, height_fac=15, \
                     title = 'TempPC 0: %.1f%% of variance' % (100*vrncs[0]))
# second through fifth temperature PC:
Map.contourPlotOnMap(lon, lat, TempPC[1] , width_fac=18, height_fac=15, \
                     title = 'TempPC 1: %.1f%% of variance' % (100*vrncs[1]))
Map.contourPlotOnMap(lon, lat, TempPC[2] , width_fac=18, height_fac=15, \
                     title = 'TempPC 2: %.1f%% of variance' % (100*vrncs[2]))
Map.contourPlotOnMap(lon, lat, TempPC[3] , width_fac=18, height_fac=15, \
                     title = 'TempPC 3: %.1f%% of variance' % (100*vrncs[3]))
Map.contourPlotOnMap(lon, lat, TempPC[4] , width_fac=18, height_fac=15, \
                     title = 'TempPC 4: %.1f%% of variance' % (100*vrncs[4]))
Map.contourPlotOnMap(lon, lat, TempPC[28] , width_fac=18, height_fac=15, \
                     title = 'TempPC 28: %.1f%% of variance' % (100*vrncs[28]))
# Out:
# ('centre at: ', -84.302951814208981, 42.476200103753712)
# ('centre at: ', -84.302951814208981, 42.476200103753712)
# ('centre at: ', -84.302951814208981, 42.476200103753712)
# ('centre at: ', -84.302951814208981, 42.476200103753712)
# ('centre at: ', -84.302951814208981, 42.476200103753712)
# ('centre at: ', -84.302951814208981, 42.476200103753712)

# %%
PressPC = transform_params['pcas'][2].components_

# get longitude and latitude of stations 
lon, lat = Util.getStationLonLat(stations)

# get variance explained by each PC
vrncs = transform_params['pcas'][2].explained_variance_ratio_

# first PC is very homogeneous so pattern not interesting
Map.contourPlotOnMap(lon, lat, PressPC[0] , width_fac=18, height_fac=15, \
                     title = 'PressPC 0: %.1f%% of variance' % (100*vrncs[0]))
# second through fifth temperature PC:
Map.contourPlotOnMap(lon, lat, PressPC[1] , width_fac=18, height_fac=15, \
                     title = 'PressPC 1: %.1f%% of variance' % (100*vrncs[1]))
Map.contourPlotOnMap(lon, lat, PressPC[2] , width_fac=18, height_fac=15, \
                     title = 'PressPC 2: %.1f%% of variance' % (100*vrncs[2]))
Map.contourPlotOnMap(lon, lat, PressPC[3] , width_fac=18, height_fac=15, \
                     title = 'PressPC 3: %.1f%% of variance' % (100*vrncs[3]))
# Out:
# ('centre at: ', -84.302951814208981, 42.476200103753712)
# ('centre at: ', -84.302951814208981, 42.476200103753712)
# ('centre at: ', -84.302951814208981, 42.476200103753712)
# ('centre at: ', -84.302951814208981, 42.476200103753712)

# %%
stations = Util.getStationList()
features = ['TempMax']
ncomp = None

pcaData, transform_params = PCA.pcaConvert(stations, features, '2005-01-01', '2010-12-31', ncomp)
TempPC = transform_params['pcas'][0].components_
# get variance explained by each PC
vrncs = transform_params['pcas'][0].explained_variance_ratio_

Map.contourPlotOnMap(lon, lat, TempPC[28] , width_fac=18, height_fac=15, \
                     title = 'TempPC 28: %.1f%% of variance' % (100*vrncs[28]))
# Out:
# ('centre at: ', -84.302951814208981, 42.476200103753712)
