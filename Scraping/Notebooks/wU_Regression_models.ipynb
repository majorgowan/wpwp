# %% [markdown]
# ## More sophisticated regression models

# %%
cd I:/wpwp/Scraping
# Out:
# I:\wpwp\Scraping

# %%
cd D:/mfruman/Documents/wpwp/Scraping
# Out:
# [Error 21] The device is not ready: u'D:/mfruman/Documents/wpwp/Scraping'
# C:\Users\mfruman

# %%
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
import wURegression as Reg
reload(Reg)
# Out:
# <module 'wURegression' from 'wURegression.pyc'>

# %% [markdown]
# ### One-city, single-day model

# %%
# regression model using data from one city on a single day
# to predict maximum temperature the next day
featureData, target, model_params = Reg.oneCityModel('CYYZ','2005-01-01','2010-12-31',\
                                                     ['TempMax','dailyTempRange',\
                                                     'PressMax','dailyPressRange',\
                                                     'HumidityMean',\
                                                     'isWesterly','isSoutherly',\
                                                     'isFoggy'],targetVar='TempMax',lag=1,scale=True)
# Out:
# R^2: 0.895186087769
# Regression coefficients (scaled, sorted):
#   intercept:	13.198630137
#   TempMax:	10.2870175391
#   dailyTempRange:	1.28459386258
#   isWesterly:	-0.796796180055
#   PressMax:	0.531104324849
#   HumidityMean:	0.211797309015
#   dailyPressRange:	0.18983101113
#   isFoggy:	0.113852945677
#   isSoutherly:	-0.0427820592969

# %%
# out-of-sample prediction
date_list, pred, target, model_perf = Reg.oneCityPredict(model_params, \
                                                         '2011-01-01', '2012-12-31', \
                                                         actual=True)
# Out:
# R^2_mean:	0.871880589955
# R^2_base:	0.188065301175
# RMSE:		3.91648980235
# RMSE_base:	4.34646762578

# %%
# plot comparison
Reg.plotModelPred(date_list, pred, target)
Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300)

# %% [markdown]
# ### One-city, multi-day model

# %%
# using data from one city on multiple days ("Taylor model")
pred0 = pred[2:]  # save simple model prediction (for comparison plot)
featureData, target, model_params = Reg.oneCityTaylorModel('CYYZ','2005-01-01','2010-12-31',\
                                                           ['TempMax','dailyTempRange',\
                                                           'PressMax','dailyPressRange',\
                                                           'HumidityMean',\
                                                           'isWesterly','isSoutherly',\
                                                           'isFoggy'],targetVar='TempMax',lag=1,order=2,scale=True)
# Out:
# R^2: 0.907795491818
# Regression coefficients (scaled, sorted):
#   intercept:	13.2061243144
#   0th deriv of TempMax:	10.4536455127
#   1th deriv of TempMax:	-1.59983449654
#   0th deriv of dailyTempRange:	1.44576269876
#   1th deriv of isSoutherly:	0.915660794913
#   1th deriv of PressMax:	0.885946073547
#   0th deriv of isWesterly:	-0.804667701823
#   2th deriv of TempMax:	0.697555513584
#   1th deriv of isWesterly:	0.60418076073
#   2th deriv of PressMax:	-0.447248577644
#   1th deriv of dailyPressRange:	0.431651529803
#   2th deriv of isSoutherly:	-0.394717106637
#   1th deriv of HumidityMean:	0.350881351057
#   0th deriv of dailyPressRange:	-0.343900320669
#   2th deriv of isWesterly:	-0.313439241676
#   0th deriv of isSoutherly:	-0.252224726617
#   2th deriv of dailyPressRange:	-0.250337928515
#   0th deriv of PressMax:	0.246124040771
#   0th deriv of HumidityMean:	0.216352165137
#   2th deriv of HumidityMean:	-0.184771294194
#   2th deriv of isFoggy:	-0.171049346467
#   2th deriv of dailyTempRange:	-0.16638561231
#   0th deriv of isFoggy:	0.160381578765
#   1th deriv of dailyTempRange:	0.121536231424
#   1th deriv of isFoggy:	0.0834767587636

# %%
# out-of-sample prediction
date_list, pred, target, model_perf = Reg.oneCityTaylorPredict(model_params, \
                                                               '2011-01-01', '2012-12-31', \
                                                               actual=True)
# Out:
# R^2_mean:	0.89250321933
# R^2_base:	0.315600207993
# RMSE:		3.5847396255
# RMSE_base:	4.33313961246

# %%
# plot comparison
Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300)

# %%
# compare errors from simple and "Taylor" models
err_base = np.array(target[200:301]) - np.array(target[200:301])
err0 = np.array(pred0[200:301]) - np.array(target[200:301])
err2 = np.array(pred[200:301]) - np.array(target[200:301])

fig = plt.figure()
p1 = plt.plot(date_list[200:301], err0, color='blue')
p2 = plt.plot(date_list[200:301], err2, color='cyan')
p3 = plt.plot(date_list[200:301], err_base, color='red', linestyle='--')
plt.legend(('simple','Taylor2','baseline'))
plt.plot(date_list[200:301], np.zeros((61,)), color='black')
plt.scatter(date_list[200:301], err0, color='blue')
plt.scatter(date_list[200:301], err2, color='cyan')

fig.autofmt_xdate()
plt.show()

# %%
# using data from one city on multiple days ("Taylor model") ... predict two-days ahead
featureData, target, model_params = Reg.oneCityTaylorModel('CYYZ','2005-01-01','2010-12-31',\
                                                           ['TempMax','dailyTempRange',\
                                                           'PressMax','dailyPressRange',\
                                                           'HumidityMean',\
                                                           'isWesterly','isSoutherly',\
                                                           'isFoggy'],targetVar='TempMax',lag=2,order=2,scale=True)
# Out:
# R^2: 0.838067566649
# Regression coefficients (scaled, sorted):
#   intercept:	13.2117055327
#   0th deriv of TempMax:	10.2318328607
#   1th deriv of TempMax:	-2.08260790112
#   1th deriv of isWesterly:	1.28803766117
#   0th deriv of isWesterly:	-1.23518668833
#   1th deriv of isSoutherly:	1.20037078533
#   1th deriv of PressMax:	1.1327141517
#   0th deriv of dailyTempRange:	1.05168332153
#   0th deriv of isSoutherly:	-0.934708731934
#   2th deriv of TempMax:	0.870378402328
#   0th deriv of dailyPressRange:	0.854636890619
#   2th deriv of isWesterly:	-0.807557160629
#   2th deriv of PressMax:	-0.694041171247
#   1th deriv of isFoggy:	0.646395331012
#   2th deriv of isSoutherly:	-0.565765554426
#   2th deriv of isFoggy:	-0.509258868152
#   1th deriv of HumidityMean:	0.447868975578
#   0th deriv of PressMax:	0.433525834009
#   2th deriv of dailyPressRange:	0.372030885431
#   2th deriv of dailyTempRange:	-0.332556581962
#   1th deriv of dailyPressRange:	-0.284763578665
#   1th deriv of dailyTempRange:	0.273890252185
#   2th deriv of HumidityMean:	-0.222627350891
#   0th deriv of HumidityMean:	-0.11008195483
#   0th deriv of isFoggy:	-0.0641569769246

# %%
date_list, pred, target, model_perf = Reg.oneCityTaylorPredict(model_params, \
                                                               '2011-01-01', '2012-12-31', \
                                                               actual=True)
Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300)
# Out:
# R^2_mean:	0.827792450695
# R^2_base:	0.347148544571
# RMSE:		4.53578570011
# RMSE_base:	5.613650096

# %% [markdown]
# ### Multi-city, multi-day model

# %%
# using data from multiple cities on multiple days

# get list of all available stations
import wUMapPlots as Map
stations = Map.getStationList()
# move target station to front
targStation = 'CYYZ'
stations = [targStation] + [s for s in stations if s != targStation]
# build model
featureData, target, model_params = Reg.multiCityTaylorModel(stations,'2005-01-01','2010-12-31',\
                                                           ['TempMax','dailyTempRange',\
                                                           'PressMax','dailyPressRange',\
                                                           'HumidityMean',\
                                                           'isWesterly','isSoutherly',\
                                                           'isFoggy'],targetVar='TempMax',lag=1,order=1,scale=True,verbose=False)
# Out:
# R^2: 0.968236122308

# %%
# predict
date_list, pred, target, model_perf = Reg.multiCityTaylorPredict(model_params, \
                                                                 '2011-01-01', '2012-12-31', \
                                                                 actual=True)
Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300)
# Out:
# R^2_mean:	0.943622816199
# R^2_base:	0.640265997581
# RMSE:		2.59723494763

# %%
# Some statistics of this rather decent prediction!
import matplotlib.mlab as mlab

lag = 1

# error of regression model
err = np.array(pred[lag:]) - np.array(target[lag:])
# error of "baseline model" (predicted temp same as temp on prediction day)
err_base = np.array(target[:-lag]) - np.array(target[lag:])

# histogram of day-over-day changes in daily max temperature
n, bins_base, patches = plt.hist(err_base, 30, normed=1, facecolor='blue', alpha=0.8)
# histogram of errors by prediction model
n, bins, patches = plt.hist(err, 30, normed=1, facecolor='green', alpha=0.5)

# add a 'best fit' normal distribution curves
mu = np.mean(err)
mu_base = np.mean(err_base)
sigma = np.std(err)
sigma_base = np.std(err_base)
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=2)
y_base = mlab.normpdf(bins_base, mu_base, sigma_base)
l_base = plt.plot(bins_base, y_base, 'r', linewidth=2)

plt.xlabel('error in predicted maximum Temperature')
plt.title('Baseline (blue): mean = %.3f, sigma = %.2f; Reg (green): mean = %.3f, sigma= %.2f' \
          % (mu_base, sigma_base, mu, sigma))
plt.xlim([-18,18])
plt.grid(True)
plt.show()

# Extreme events:
print("Performance when change from prediction day is larger:\n")
for ii in range(10):
     extreme = [(err[i],err_base[i]) for i in range(len(err)) \
                if (abs(err_base[i]) > ii*sigma_base) & (abs(err_base[i]) < (ii+1)*sigma_base)]
     better = [int(abs(e[0]) < abs(e[1])) for e in extreme]
     print('There were %d %d-sigma events!' % (len(extreme),ii))
     if (len(extreme) > 0):
          print('Regression beats baseline %.1f%% of the time' \
                % (float(100*sum(better)) / float(len(better))))
          rmse = np.sqrt(np.mean([e[1]*e[1] for e in extreme]))
          print('Baseline RMSE : \t%.2f' % rmse)
          rmse = np.sqrt(np.mean([e[0]*e[0] for e in extreme]))
          print('Regression RMSE : \t%.2f\n' % rmse)
     else:
          break
# Out:
# Performance when change from prediction day is larger:
#
# There were 460 0-sigma events!
# Regression beats baseline 60.9% of the time
# Baseline RMSE : 	2.39
# Regression RMSE : 	2.26
#
# There were 151 1-sigma events!
# Regression beats baseline 92.1% of the time
# Baseline RMSE : 	6.13
# Regression RMSE : 	3.15
#
# There were 31 2-sigma events!
# Regression beats baseline 100.0% of the time
# Baseline RMSE : 	10.15
# Regression RMSE : 	3.00
#
# There were 11 3-sigma events!
# Regression beats baseline 100.0% of the time
# Baseline RMSE : 	14.05
# Regression RMSE : 	5.76
#
# There were 0 4-sigma events!

# %%
# predict something else?  How about maximum SLP

# build model
print('training . . . ')
featureData, target, model_params = Reg.multiCityTaylorModel(stations,'2005-01-01','2010-12-31',\
                                                           ['TempMax','dailyTempRange',\
                                                           'PressMax','dailyPressRange',\
                                                           'HumidityMean',\
                                                           'isWesterly','isSoutherly',\
                                                           'isFoggy'],targetVar='PressMax',lag=1,order=1,scale=True,verbose=False)

# predict
print('testing . . .')
date_list, pred, target, model_perf = Reg.multiCityTaylorPredict(model_params, \
                                                                 '2011-01-01', '2012-12-31', \
                                                                 actual=True)
Reg.plotModelPred(date_list, pred, target)
Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300)
# Out:
# R^2: 0.87903410107
# R^2_mean:	0.774165359276
# R^2_base:	0.688215943038
# RMSE:		3.34086604828

# %%
# statistics
lag = 1

# error of regression model
err = np.array(pred[lag:]) - np.array(target[lag:])
# error of "baseline model" (predicted temp same as temp on prediction day)
err_base = np.array(target[:-lag]) - np.array(target[lag:])

# histogram of day-over-day changes in daily max temperature
n, bins_base, patches = plt.hist(err_base, 30, normed=1, facecolor='blue', alpha=0.8)
# histogram of errors by prediction model
n, bins, patches = plt.hist(err, 30, normed=1, facecolor='green', alpha=0.5)

# add a 'best fit' normal distribution curves
mu = np.mean(err)
mu_base = np.mean(err_base)
sigma = np.std(err)
sigma_base = np.std(err_base)
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=2)
y_base = mlab.normpdf(bins_base, mu_base, sigma_base)
l_base = plt.plot(bins_base, y_base, 'r', linewidth=2)

plt.xlabel('error in predicted maximum SLP')
plt.title('Baseline (blue): mean = %.3f, sigma = %.2f; Reg (green): mean = %.3f, sigma= %.2f' \
          % (mu_base, sigma_base, mu, sigma))
plt.xlim([-18,18])
plt.grid(True)
plt.show()

# Extreme events:
print("Performance when change from prediction day is larger:\n")
for ii in range(10):
     extreme = [(err[i],err_base[i]) for i in range(len(err)) \
                if (abs(err_base[i]) > ii*sigma_base) & (abs(err_base[i]) < (ii+1)*sigma_base)]
     better = [int(abs(e[0]) < abs(e[1])) for e in extreme]
     print('There were %d %d-sigma events!' % (len(extreme),ii))
     if (len(extreme) > 0):
          print('Regression beats baseline %.1f%% of the time' \
                % (float(100*sum(better)) / float(len(better))))
          rmse = np.sqrt(np.mean([e[1]*e[1] for e in extreme]))
          print('Baseline RMSE : \t%.2f' % rmse)
          rmse = np.sqrt(np.mean([e[0]*e[0] for e in extreme]))
          print('Regression RMSE : \t%.2f\n' % rmse)
     else:
          break
# Out:
# Performance when change from prediction day is larger:
#
# There were 526 0-sigma events!
# Regression beats baseline 56.3% of the time
#
# There were 147 1-sigma events!
# Regression beats baseline 97.3% of the time
#
# There were 33 2-sigma events!
# Regression beats baseline 100.0% of the time
#
# There were 9 3-sigma events!
# Regression beats baseline 100.0% of the time
#
# There were 1 4-sigma events!
# Regression beats baseline 100.0% of the time
#
# There were 0 5-sigma events!

# %% [markdown]
# ### Advection model

# %%
# using data from multiple cities but only components advected towards target city
# get list of all available stations
import wUMapPlots as Map
stations = Map.getStationList()
# move target station to front
targStation = 'CYYZ'
stations = [targStation] + [s for s in stations if s != targStation]
# build model
featureData, target, model_params = Reg.advectionTaylorModel(stations,'2005-01-01','2010-12-31',\
                                                             ['TempMax','PressMax'],targetVar='TempMax',\
                                                             lag=1,order=1,verbose=False)
# Out:
# R^2: 0.933561505489

# %%
# predict
date_list, pred, target, model_perf = Reg.advectionTaylorPredict(model_params, \
                                                                 '2011-01-01', '2012-12-31', \
                                                                 actual=True)
Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300)
# Out:
# R^2_mean:	0.926001768919
# R^2_base:	0.527828847704
# RMSE:		2.9755703196

# %% [markdown]
# ### Predictability by station

# %%
# comparison of performance by station
# one-station Taylor model:
stations = Map.getStationList()
reload(Reg)
perfList = Reg.compareStationsOneCity(stations, \
                                      '2005-01-01', '2010-12-31', '2011-01-01', '2012-12-31', \
                                      ['TempMax','dailyTempRange',\
                                      'PressMax','dailyPressRange',\
                                      'HumidityMean','isWesterly','isSoutherly',\
                                      'isFoggy'], targetVar='TempMax', \
                                      lag=1, order=1)
# Out:
# CYYZ:
# R^2: 0.90560554657
# R^2_mean:	0.887777890736
# R^2_base:	0.283928252466
# RMSE:		3.66436530636
# RMSE_base:	4.33032500832
#
# CYUL:
# R^2: 0.91612235809
# R^2_mean:	0.906571418339
# R^2_base:	0.270008105924
# RMSE:		3.65570224073
# RMSE_base:	4.27869959605
#
# CYOW:
# R^2: 0.904561765664
# R^2_mean:	0.891811112053
# R^2_base:	0.239293667343
# RMSE:		4.12380940183
# RMSE_base:	4.72813718151
#
# KDTW:
# R^2: 0.904548081948
# R^2_mean:	0.894888152942
# R^2_base:	0.273897453876
# RMSE:		3.66705463157
# RMSE_base:	4.30346623938
#
# KPIT:
# R^2: 0.881336076787
# R^2_mean:	0.862281036359
# R^2_base:	0.28481074969
# RMSE:		3.90151473563
# RMSE_base:	4.61341754009
#
# KORD:
# R^2: 0.893206051702
# R^2_mean:	0.875799387723
# R^2_base:	0.229899371502
# RMSE:		4.04072964372
# RMSE_base:	4.60453792984
#
# KPHL:
# R^2: 0.880597432024
# R^2_mean:	0.861097835965
# R^2_base:	0.189018248872
# RMSE:		3.66598212433
# RMSE_base:	4.07084720693
#
# KIND:
# R^2: 0.894653471263
# R^2_mean:	0.880468599681
# R^2_base:	0.237908198957
# RMSE:		3.83678601633
# RMSE_base:	4.39505115133
#
# KMKE:
# R^2: 0.886081600587
# R^2_mean:	0.864261152929
# R^2_base:	0.264184651573
# RMSE:		4.09344746207
# RMSE_base:	4.77204795669
#
# KMSP:
# R^2: 0.920410515899
# R^2_mean:	0.903475264989
# R^2_base:	0.238452130566
# RMSE:		3.97866042342
# RMSE_base:	4.55919607622
#
# KCVG:
# R^2: 0.887514735015
# R^2_mean:	0.862053912172
# R^2_base:	0.199944931822
# RMSE:		3.89235122907
# RMSE_base:	4.35163120008
#
# CYSB:
# R^2: 0.907290923711
# R^2_mean:	0.902039012403
# R^2_base:	0.300899591433
# RMSE:		3.92114958413
# RMSE_base:	4.68968456183
#
# CYQT:
# R^2: 0.883807786577
# R^2_mean:	0.88371411989
# R^2_base:	0.133793308325
# RMSE:		4.13444321128
# RMSE_base:	4.44228342524
#
# KBUF:
# R^2: 0.890802810739
# R^2_mean:	0.879901622811
# R^2_base:	0.262311326495
# RMSE:		3.74421295757
# RMSE_base:	4.35937254014
#
# KBNA:
# R^2: 0.855572344634
# R^2_mean:	0.840990480368
# R^2_base:	0.199984740135
# RMSE:		3.7953824202
# RMSE_base:	4.24332607592
#
# KDSM:
# R^2: 0.894727552163
# R^2_mean:	0.872360353435
# R^2_base:	0.223783554722
# RMSE:		4.32749673008
# RMSE_base:	4.91185263381
#
# CYWG:
# R^2: 0.921773615986
# R^2_mean:	0.907833249573
# R^2_base:	0.211260464239
# RMSE:		4.41917951973
# RMSE_base:	4.97593660835
#
# KMEM:
# R^2: 0.864137782222
# R^2_mean:	0.862113918811
# R^2_base:	0.250121589166
# RMSE:		3.47498509872
# RMSE_base:	4.01289246037
#
# KCLT:
# R^2: 0.848948135876
# R^2_mean:	0.850390910389
# R^2_base:	0.221437373925
# RMSE:		3.21843634786
# RMSE_base:	3.64752391727
#
# KSTL:
# R^2: 0.860120952511
# R^2_mean:	0.859710287738
# R^2_base:	0.255574971195
# RMSE:		4.16220186081
# RMSE_base:	4.82405950094
#
# KCLE:
# R^2: 0.883945578748
# R^2_mean:	0.861042959622
# R^2_base:	0.274085506633
# RMSE:		4.01368108297
# RMSE_base:	4.71085924088
#
# KBOS:
# R^2: 0.838591120918
# R^2_mean:	0.84172740465
# R^2_base:	0.270492486455
# RMSE:		3.7982978839
# RMSE_base:	4.4470717543
#
# KJFK:
# R^2: 0.887249237674
# R^2_mean:	0.878982136665
# R^2_base:	0.249135294184
# RMSE:		3.2077962915
# RMSE_base:	3.70191067709
#
# KMCI:
# R^2: 0.863475035678
# R^2_mean:	0.859376948514
# R^2_base:	0.233278378135
# RMSE:		4.31324282654
# RMSE_base:	4.92589390132
#
# KOKC:
# R^2: 0.827428588813
# R^2_mean:	0.853942980034
# R^2_base:	0.221807456234
# RMSE:		4.12694016987
# RMSE_base:	4.67826307562
#
# KIAD:
# R^2: 0.854137799292
# R^2_mean:	0.842514093692
# R^2_base:	0.210621773529
# RMSE:		3.87861077848
# RMSE_base:	4.36549634051
#
# CYGK:
# R^2: 0.902155609312
# R^2_mean:	0.88073545531
# R^2_base:	0.27772211442
# RMSE:		3.71157528721
# RMSE_base:	4.36723051051
#
# KGRB:
# R^2: 0.910340749441
# R^2_mean:	0.903320268241
# R^2_base:	0.173075736018
# RMSE:		3.67621273622
# RMSE_base:	4.0426651221
#
# KROC:
# R^2: 0.881723096988
# R^2_mean:	0.856787907614
# R^2_base:	0.241021630467
# RMSE:		4.07598214805
# RMSE_base:	4.67861785366

# %%
reload(Map)
stations = [a['station'] for a in perfList]
R2 = [a['R2_base'] for a in perfList]
RMSE = [a['RMSE'] for a in perfList]
Map.contourPlotStationsOnMap(stations, R2, title='R2, one-city models', width_fac=18, height_fac=15)
Map.contourPlotStationsOnMap(stations, RMSE, title='RMSE, one-city models', width_fac=18, height_fac=15)
# Out:
# ('centre at: ', -84.302951814208981, 42.476200103753712)
# ('centre at: ', -84.302951814208981, 42.476200103753712)

# %%
# multi-station Taylor model:
stations = Map.getStationList()
reload(Reg)
perfList = Reg.compareStationsMultiCity(stations, \
                                        '2005-01-01', '2010-12-31', '2011-01-01', '2012-12-31', \
                                        ['TempMax','dailyTempRange',\
                                        'PressMax','dailyPressRange',\
                                        'HumidityMean','isWesterly','isSoutherly',\
                                        'isFoggy'], targetVar='TempMax', \
                                        lag=1, order=1)
# Out:
# CYYZ:
# R^2: 0.968236122308
# R^2_mean:	0.943622816199
# R^2_base:	0.640265997581
# RMSE:		2.59723494763
#
# CYUL:
# R^2: 0.96746070968
# R^2_mean:	0.941242837537
# R^2_base:	0.540908664625
# RMSE:		2.89908763897
#
# CYOW:
# R^2: 0.964383717319
# R^2_mean:	0.936364575697
# R^2_base:	0.552561532266
# RMSE:		3.16269074825
#
# KDTW:
# R^2: 0.967911452501
# R^2_mean:	0.941081561339
# R^2_base:	0.592997083369
# RMSE:		2.74547289854
#
# KPIT:
# R^2: 0.963370218266
# R^2_mean:	0.931434491496
# R^2_base:	0.643932009595
# RMSE:		2.75289235172
#
# KORD:
# R^2: 0.962008244838
# R^2_mean:	0.92034261839
# R^2_base:	0.506087783968
# RMSE:		3.23601807487
#
# KPHL:
# R^2: 0.959067513235
# R^2_mean:	0.922105843257
# R^2_base:	0.545214143518
# RMSE:		2.7452903096
#
# KIND:
# R^2: 0.963613205168
# R^2_mean:	0.94182466136
# R^2_base:	0.629093706907
# RMSE:		2.67667741761
#
# KMKE:
# R^2: 0.955391933379
# R^2_mean:	0.914921539855
# R^2_base:	0.538805300425
# RMSE:		3.24076062196
#
# KMSP:
# R^2: 0.959435292026
# R^2_mean:	0.924267251654
# R^2_base:	0.402493949942
# RMSE:		3.52419088627
#
# KCVG:
# R^2: 0.963131153227
# R^2_mean:	0.932720495807
# R^2_base:	0.609794600471
# RMSE:		2.71830835036
#
# CYSB:
# R^2: 0.959101692186
# R^2_mean:	0.930211034574
# R^2_base:	0.501949751224
# RMSE:		3.30963585468
#
# CYQT:
# R^2: 0.947416984663
# R^2_mean:	0.911529376006
# R^2_base:	0.340987517588
# RMSE:		3.60622719533
#
# KBUF:
# R^2: 0.967342711997
# R^2_mean:	0.94204254692
# R^2_base:	0.644003876801
# RMSE:		2.60103752929
#
# KBNA:
# R^2: 0.953695802994
# R^2_mean:	0.903410696995
# R^2_base:	0.514035911043
# RMSE:		2.95807032692
#
# KDSM:
# R^2: 0.948698769564
# R^2_mean:	0.894919131338
# R^2_base:	0.360970509284
# RMSE:		3.92650160258
#
# CYWG:
# R^2: 0.944539909566
# R^2_mean:	0.906743896958
# R^2_base:	0.201938062488
# RMSE:		4.4452187554
#
# KMEM:
# R^2: 0.948592169815
# R^2_mean:	0.903632435284
# R^2_base:	0.475915511835
# RMSE:		2.90508052033
#
# KCLT:
# R^2: 0.936812594796
# R^2_mean:	0.90454099032
# R^2_base:	0.503233276452
# RMSE:		2.57083614043
#
# KSTL:
# R^2: 0.950261814978
# R^2_mean:	0.909124263823
# R^2_base:	0.517782370277
# RMSE:		3.34991816528
#
# KCLE:
# R^2: 0.964491741841
# R^2_mean:	0.933295199213
# R^2_base:	0.651532721649
# RMSE:		2.78087283388
#
# KBOS:
# R^2: 0.928627632769
# R^2_mean:	0.893699748283
# R^2_base:	0.510042580981
# RMSE:		3.11281496745
#
# KJFK:
# R^2: 0.954231932011
# R^2_mean:	0.919049108933
# R^2_base:	0.497733926778
# RMSE:		2.62357121521
#
# KMCI:
# R^2: 0.933602303258
# R^2_mean:	0.881024462592
# R^2_base:	0.351307512962
# RMSE:		3.96738628254
#
# KOKC:
# R^2: 0.90404780642
# R^2_mean:	0.861085195126
# R^2_base:	0.259861214499
# RMSE:		4.02477143191
#
# KIAD:
# R^2: 0.952355797655
# R^2_mean:	0.91408161407
# R^2_base:	0.569344935705
# RMSE:		2.86482704444
#
# CYGK:
# R^2: 0.959088183042
# R^2_mean:	0.925021044437
# R^2_base:	0.54592002487
# RMSE:		2.94287821708
#
# KGRB:
# R^2: 0.965851308181
# R^2_mean:	0.936686787094
# R^2_base:	0.458467343359
# RMSE:		2.9749528938
#
# KROC:
# R^2: 0.966155692538
# R^2_mean:	0.937447482586
# R^2_base:	0.668491627447
# RMSE:		2.69379674902

# %%
stations = [a['station'] for a in perfList]
R2 = [a['R2_base'] for a in perfList]
RMSE = [a['RMSE'] for a in perfList]
Map.contourPlotStationsOnMap(stations, R2, title='R2, multi-city models', width_fac=18, height_fac=15)
Map.contourPlotStationsOnMap(stations, RMSE, title='RMSE, multi-city models', width_fac=18, height_fac=15)
# Out:
# ('centre at: ', -84.302951814208981, 42.476200103753712)
# ('centre at: ', -84.302951814208981, 42.476200103753712)

# %% [markdown]
# ### Truncated PCA model

# %%
# PCA models
# using data from multiple cities on multiple days
reload(Reg)
# get list of all available stations
import wUMapPlots as Map
stations = Map.getStationList()
# move target station to front
targStation = 'CYYZ'
stations = [targStation] + [s for s in stations if s != targStation]
# build model
featureData, target, model_params = Reg.pcaTaylorModel(stations,'2005-01-01','2010-12-31',\
                                                           ['TempMax','dailyTempRange','PressMax','dailyPressRange',\
                                                            'HumidityMean', \
                                                            'isSoutherly','isWesterly','isFoggy'], \
                                                           ncomp=[8, 5, 8, 5, 5, 5, 5, 5], \
                                                           targetVar='TempMax',lag=1,order=1,verbose=False)
# Out:
# R^2: 0.957781618476

# %%
# predict
reload(Reg)
date_list, pred, target, model_perf = Reg.pcaTaylorPredict(model_params, \
                                                           '2011-01-01', '2012-12-31', \
                                                           actual=True)
Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300)
# Out:
# R^2_mean:	0.94639567301
# R^2_base:	0.657959163708
# RMSE:		2.53255842386

# %%
# two days ahead!
# build model
featureData, target, model_params = Reg.pcaTaylorModel(stations,'2005-01-01','2010-12-31',\
                                                           ['TempMax','dailyTempRange','PressMax','dailyPressRange',\
                                                            'HumidityMean', \
                                                            'isSoutherly','isWesterly','isFoggy'], \
                                                           ncomp=[8, 5, 8, 5, 5, 5, 5, 5], \
                                                           targetVar='TempMax',lag=2,order=1,verbose=False)
# predict
date_list, pred, target, model_perf = Reg.pcaTaylorPredict(model_params, \
                                                           '2011-01-01', '2012-12-31', \
                                                           actual=True)
Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300)
# Out:
# R^2: 0.913392865263
# R^2_mean:	0.899468572418
# R^2_base:	0.61811911988
# RMSE:		3.46665651133

# %%
# model with only one PC per feature!!
# build model
print('training . . .')
featureData, target, model_params = Reg.pcaTaylorModel(stations,'2005-01-01','2010-12-31',\
                                                           ['TempMax','dailyTempRange','PressMax','dailyPressRange',\
                                                            'HumidityMean', \
                                                            'isSoutherly','isWesterly','isFoggy'], \
                                                           ncomp=[1, 1, 1, 1, 1, 1, 1, 1], \
                                                           targetVar='TempMax',lag=1,order=1,verbose=False)
print('testing . . .')
date_list, pred, target, model_perf = Reg.pcaTaylorPredict(model_params, \
                                                           '2011-01-01', '2012-12-31', \
                                                           actual=True)
Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300)
# Out:
# training . . .
# R^2: 0.933996117759
# testing . . .
# R^2_mean:	0.928990907351
# R^2_base:	0.546902073066
# RMSE:		2.91485214838

# %% [markdown]
# ### Truncated PCA model with smoothing of training data

# %%
reload(Reg)
# build model
print('training . . .')
featureData, target, model_params = Reg.pcaTaylorModel(stations,'2005-01-01','2010-12-31',\
                                                           ['TempMax','dailyTempRange','PressMax','dailyPressRange',\
                                                            'HumidityMean', \
                                                            'isSoutherly','isWesterly','isFoggy'], \
                                                           ncomp=[29, 1, 1, 1, 1, 1, 1, 1], \
                                                           targetVar='TempMax',lag=1,order=1, \
                                                           smooth_window=3, verbose=False)
print('testing . . .')
date_list, pred, target, model_perf = Reg.pcaTaylorPredict(model_params, \
                                                           '2011-01-01', '2012-12-31', \
                                                           actual=True)
Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300)
# Out:
# training . . .
# R^2: 0.97555964202
# testing . . .
# R^2_mean:	0.926902633108
# R^2_base:	0.533577121354
# RMSE:		2.95740236348

# %% [markdown]
# ### Multi-city, multi-day model with interaction terms

# %%
# using data from multiple cities on multiple days ... with interactions
reload(Reg)
# get list of all available stations
import wUMapPlots as Map
stations = Map.getStationList()
# move target station to front
targStation = 'CYYZ'
stations = [targStation] + [s for s in stations if s != targStation]
# build model
featureData, target, model_params = Reg.multiCityInteractionModel(stations,'2005-01-01','2010-12-31',\
                                                                  ['TempMax','dailyTempRange', \
                                                                   'TempMax:WindMeanX','TempMax:WindMeanY', \
                                                                   'TempMax:isFoggy',\
                                                                   'isWesterly','isSoutherly',\
                                                                   'isFoggy', \
                                                                   'PressMax','dailyPressRange', \
                                                                   'HumidityMean'], \
                                                                  targetVar='TempMax',lag=1,order=1,scale=True,verbose=False)
# Out:
# R^2: 0.972782505819

# %%
# predict
date_list, pred, target, model_perf = Reg.multiCityInteractionPredict(model_params, \
                                                                      '2011-01-01', '2012-12-31', \
                                                                      actual=True)

Reg.plotModelPred(date_list, pred, target, startIndex=200, endIndex=300)
# Out:
# R^2_mean:	0.939889630203
# R^2_base:	0.616445120954
# RMSE:		2.68184855186

# %% [markdown]
# ### Multi-model average

# %%
# multimodel average
pred_list = []
# interactions . . .
print('\nModel with interactions . . .')
featureData, target, model_params = Reg.multiCityInteractionModel(stations,'2005-01-01','2010-12-31',\
                                                                  ['TempMax','dailyTempRange', \
                                                                   'TempMax:WindMeanX','TempMax:WindMeanY', \
                                                                   'TempMax:isFoggy',\
                                                                   'PressMax','dailyPressRange', \
                                                                   'HumidityMean'], \
                                                                  targetVar='TempMax',lag=1,order=1,scale=True,verbose=False)
date_list, pred, target, model_perf_inter = Reg.multiCityInteractionPredict(model_params, \
                                                                            '2011-01-01', '2012-12-31', \
                                                                            actual=True)
pred_list.append(pred)

# no interactions
print('\nModel without interactions . . .')
featureData, target, model_params = Reg.multiCityInteractionModel(stations,'2005-01-01','2010-12-31',\
                                                                  ['TempMax','dailyTempRange', \
                                                                   'isWesterly','isSoutherly',\
                                                                   'isFoggy', \
                                                                   'PressMax','dailyPressRange', \
                                                                   'HumidityMean'], \
                                                                  targetVar='TempMax',lag=1,order=1,scale=True,verbose=False)
date_list, pred, target, model_perf = Reg.multiCityInteractionPredict(model_params, \
                                                                      '2011-01-01', '2012-12-31', \
                                                                      actual=True)
pred_list.append(pred)

# truncated PCA
print('\nModel with truncated PCA . . .')
featureData, target, model_params = Reg.pcaTaylorModel(stations,'2005-01-01','2010-12-31',\
                                                       ['TempMax','dailyTempRange','PressMax','dailyPressRange',\
                                                        'HumidityMean', \
                                                        'isSoutherly','isWesterly','isFoggy'], \
                                                        ncomp=[8, 5, 8, 5, 5, 5, 5, 5], \
                                                        targetVar='TempMax',lag=1,order=1,verbose=False)
date_list, pred, target, model_perf = Reg.pcaTaylorPredict(model_params, \
                                                           '2011-01-01', '2012-12-31', \
                                                           actual=True)
pred_list.append(pred)

# advection
print('\nModel with advection components . . .')
featureData, target, model_params = Reg.advectionTaylorModel(stations,'2005-01-01','2010-12-31',\
                                                             ['TempMax','PressMax'],targetVar='TempMax',\
                                                             lag=1,order=1,verbose=False)
date_list, pred, target, model_perf = Reg.advectionTaylorPredict(model_params, \
                                                                 '2011-01-01', '2012-12-31', \
                                                                 actual=True)
pred_list.append(pred)
# Out:
# Model with interactions . . .
# R^2: 0.968780692155
# R^2_mean:	0.944801488136
# R^2_base:	0.647786919079
# RMSE:		2.56994147777
#
# Model without interactions . . .
# R^2: 0.968236122308
# R^2_mean:	0.943622816199
# R^2_base:	0.640265997581
# RMSE:		2.59723494763
#
# Model with truncated PCA . . .
# R^2: 0.957781618476
# R^2_mean:	0.94639567301
# R^2_base:	0.657959163708
# RMSE:		2.53255842386
#
# Model with advection components . . .
# R^2: 0.933561505489
# R^2_mean:	0.926001768919
# R^2_base:	0.527828847704
# RMSE:		2.9755703196

# %%
# performance of the averaged model
import numpy as np
pred_mean = [np.mean([p[ii] for p in pred_list]) for ii in range(len(date_list))]

err = np.array(pred_mean) - np.array(target)
rmse = np.sqrt(mean(err**2))
print('RMSE of average model: ' + str(rmse))
Reg.plotModelPred(date_list, pred_mean, target, startIndex=200, endIndex=300)
# Out:
# RMSE of average model: 2.38733664731

# %%
# Statistics of boffo-looking average prediction!
import matplotlib.mlab as mlab

lag = 1

# error of regression model
err = np.array(pred_mean[lag:]) - np.array(target[lag:])
# error of "baseline model" (predicted temp same as temp on prediction day)
err_base = np.array(target[:-lag]) - np.array(target[lag:])

# histogram of day-over-day changes in daily max temperature
n, bins_base, patches = plt.hist(err_base, 30, normed=1, facecolor='blue', alpha=0.8)
# histogram of errors by prediction model
n, bins, patches = plt.hist(err, 30, normed=1, facecolor='green', alpha=0.5)

# add a 'best fit' normal distribution curves
mu = np.mean(err)
mu_base = np.mean(err_base)
sigma = np.std(err)
sigma_base = np.std(err_base)
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=2)
y_base = mlab.normpdf(bins_base, mu_base, sigma_base)
l_base = plt.plot(bins_base, y_base, 'r', linewidth=2)

plt.xlabel('error in predicted maximum Temperature')
plt.title('Baseline (blue): mean = %.3f, sigma = %.2f; Reg (green): mean = %.3f, sigma= %.2f' \
          % (mu_base, sigma_base, mu, sigma))
plt.xlim([-18,18])
plt.grid(True)
plt.show()

# Extreme events:
print("Performance when change from prediction day is larger:\n")
for ii in range(10):
     extreme = [(err[i],err_base[i]) for i in range(len(err)) \
                if (abs(err_base[i]) > ii*sigma_base) & (abs(err_base[i]) < (ii+1)*sigma_base)]
     better = [int(abs(e[0]) < abs(e[1])) for e in extreme]
     print('There were %d %d-sigma events!' % (len(extreme),ii))
     if (len(extreme) > 0):
          print('Regression beats baseline %.1f%% of the time' \
                % (float(100*sum(better)) / float(len(better))))
          rmse = np.sqrt(np.mean([e[1]*e[1] for e in extreme]))
          print('Baseline RMSE : \t%.2f' % rmse)
          rmse = np.sqrt(np.mean([e[0]*e[0] for e in extreme]))
          print('Regression RMSE : \t%.2f\n' % rmse)
     else:
          break
# Out:
# Performance when change from prediction day is larger:
#
# There were 460 0-sigma events!
# Regression beats baseline 68.9% of the time
# Baseline RMSE : 	2.39
# Regression RMSE : 	1.96
#
# There were 151 1-sigma events!
# Regression beats baseline 97.4% of the time
# Baseline RMSE : 	6.13
# Regression RMSE : 	3.06
#
# There were 31 2-sigma events!
# Regression beats baseline 100.0% of the time
# Baseline RMSE : 	10.15
# Regression RMSE : 	3.45
#
# There were 11 3-sigma events!
# Regression beats baseline 100.0% of the time
# Baseline RMSE : 	14.05
# Regression RMSE : 	5.66
#
# There were 0 4-sigma events!
